# %%
from ipypb import track as tqdm
import torch
import matplotlib.pyplot as plt
import numpy as np
import itertools
import numba
import random
import diffplan
import astar
import envs
import prior_envs
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

eps = torch.finfo().eps
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
figsize = 1

env = prior_envs.f2a
diffplan.plot_graph(env, size=figsize)#, labels=[str(s) for s in env.states])

# %%
diffplan.plot_graph(prior_envs.f2c, size=figsize)

# %%
env = prior_envs.f2d
diffplan.plot_graph(prior_envs.f2d, size=figsize)

# %%
diffplan.plot_graph(prior_envs.f2f, size=figsize)

# %% [markdown]
# # blocks

# %%
diffplan.plot_graph(envs.Blocks(3, canonicalize=True), labels=True)

# %%
b = prior_envs.f2f
h = envs.compute_blocks_distance_heuristic(b)
from IPython.display import display
display(diffplan.plot_graph(b, z=h[4], size=3))
g = diffplan.plot_graph(b, z=h[21], size=3)
display(g)
g.render('figures/astar-heuristic')
# Out:
# 'figures/astar-heuristic.pdf'

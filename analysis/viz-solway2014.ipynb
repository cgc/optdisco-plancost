# %%
from ipypb import track as tqdm
import torch
import matplotlib.pyplot as plt
import numpy as np
import itertools
import numba
import random
import diffplan
import astar
import envs
import prior_envs
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

eps = torch.finfo().eps

# %%
diffplan.plot_graph(prior_envs.f2a, layout='fdp')

# %%
diffplan.plot_graph(prior_envs.f2c, layout='fdp')

# %%
diffplan.plot_graph(prior_envs.f2d)

# %%
diffplan.plot_graph(prior_envs.f2f)

# %% [markdown]
# # blocks

# %%
diffplan.plot_graph(envs.Blocks(3, canonicalize=True), labels=True)

# %%
b = envs.Blocks(3, canonicalize=False, hanoi=True)
h = envs.compute_blocks_distance_heuristic(b)
from IPython.display import display
display(diffplan.plot_graph(b, z=h[4], size=3))
display(diffplan.plot_graph(b, z=h[21], size=3))

# %%
# subway

# %%
diffplan.plot_graph(prior_envs.bala2016_hack, labels=[str(s) for s in prior_envs.bala2016_hack.states])
